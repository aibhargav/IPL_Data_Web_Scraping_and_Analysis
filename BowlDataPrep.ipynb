# %%
import pandas as pd

# %%
df = pd.read_csv("IPL23_bowling.csv")

# %%
df.iloc[10:40]
# Out:
#                BOWLING                    Team  \
# 10     Ravindra Jadeja    Chennai Super Kings
# 11         Umesh Yadav  Kolkata Knight Riders
# 12         Tim Southee  Kolkata Knight Riders
# 13        Sunil Narine  Kolkata Knight Riders
# 14  Varun Chakravarthy  Kolkata Knight Riders
# 15      Shardul Thakur  Kolkata Knight Riders
# 16          Sam Curran           Punjab Kings
# 17      Arshdeep Singh           Punjab Kings
# 18        Nathan Ellis           Punjab Kings
# 19       Sikandar Raza           Punjab Kings
# 20        Rishi Dhawan           Punjab Kings
# 21        Rahul Chahar           Punjab Kings
# 22       Harpreet Brar           Punjab Kings
# 23       Khaleel Ahmed          Delhi Capitals
# 24        Mukesh Kumar          Delhi Capitals
# 25     Chetan Sakariya          Delhi Capitals
# 26          Axar Patel          Delhi Capitals
# 27       Kuldeep Yadav          Delhi Capitals
# 28         Kyle Mayers   Lucknow Super Giants
# ...

# %%
unique_values = df['BOWLING'].unique()

# %%
unique_values
# Out:
# array(['Mohammed Shami', 'Hardik Pandya', 'Josh Little', 'Rashid Khan',
#        'Alzarri Joseph', 'Yash Dayal', 'Deepak Chahar',
#        'Tushar Deshpande', 'Rajvardhan Hangargekar', 'Mitchell Santner',
#        'Ravindra Jadeja', 'Umesh Yadav', 'Tim Southee', 'Sunil Narine',
#        'Varun Chakravarthy', 'Shardul Thakur', 'Sam Curran',
#        'Arshdeep Singh', 'Nathan Ellis', 'Sikandar Raza', 'Rishi Dhawan',
#        'Rahul Chahar', 'Harpreet Brar', 'Khaleel Ahmed', 'Mukesh Kumar',
#        'Chetan Sakariya', 'Axar Patel', 'Kuldeep Yadav', 'Kyle Mayers',
#        'Jaydev Unadkat', 'Krishnappa Gowtham', 'Avesh Khan', 'Mark Wood',
#        'Ravi Bishnoi', 'Bhuvneshwar Kumar', 'Fazalhaq Farooqi',
#        'Washington Sundar', 'T Natarajan', 'Adil Rashid', 'Umran Malik',
#        'Trent Boult', 'KM Asif', 'Jason Holder', 'Ravichandran Ashwin',
#        'Yuzvendra Chahal', 'Navdeep Saini', 'Mohammed Siraj',
#        'Reece Topley', 'Akash Deep', 'Harshal Patel', 'Karn Sharma',
# ...

# %%
len(unique_values)
# Out:
# 137

# %%
df.loc[df['BOWLING'] == 'Mohammed Shami', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Hardik Pandya', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Josh Little', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Rashid Khan', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Alzarri Joseph', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Yash Dayal', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Deepak Chahar', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Tushar Deshpande', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Rajvardhan Hangargekar', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Mitchell Santner', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Ravindra Jadeja', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Umesh Yadav', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Tim Southee', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Sunil Narine', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Varun Chakravarthy', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Shardul Thakur', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Sam Curran', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Arshdeep Singh', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Nathan Ellis', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Sikandar Raza', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Rishi Dhawan', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Rahul Chahar', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Harpreet Brar', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Khaleel Ahmed', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Mukesh Kumar', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Chetan Sakariya', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Axar Patel', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Kuldeep Yadav', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Kyle Mayers', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Jaydev Unadkat', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Krishnappa Gowtham', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Avesh Khan', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Mark Wood', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Ravi Bishnoi', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Bhuvneshwar Kumar', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Fazalhaq Farooqi', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Washington Sundar', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'T Natarajan', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Adil Rashid', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Umran Malik', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Trent Boult', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'KM Asif', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Jason Holder', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Ravichandran Ashwin', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Yuzvendra Chahal', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Navdeep Saini', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Mohammed Siraj', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Reece Topley', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Akash Deep', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Harshal Patel', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Karn Sharma', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Michael Bracewell', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Glenn Maxwell', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Jason Behrendorff', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Arshad Khan', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Jofra Archer', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Piyush Chawla', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Cameron Green', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Hrithik Shokeen', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Krunal Pandya', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Yash Thakur', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Ben Stokes', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Moeen Ali', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Anrich Nortje', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Mitchell Marsh', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'David Willey', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Shahbaz Ahmed', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Suyash Sharma', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Deepak Hooda', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Amit Mishra', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Aiden Markram', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Rovman Powell', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Sandeep Sharma', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Murugan Ashwin', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Sisanda Magala', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Dwaine Pretorius', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Kumar Kartikeya', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Lockie Ferguson', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Marco Jansen', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Mayank Markande', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Mohit Rathee', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Wayne Parnell', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Riley Meredith', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Tilak Varma', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Mustafizur Rahman', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Lalit Yadav', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Akash Singh', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Maheesh Theekshana', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Kuldeep Sen', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Adam Zampa', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Mohit Sharma', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Kagiso Rabada', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Matthew Short', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Andre Russell', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Vijaykumar Vyshak', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Wanindu Hasaranga', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Yudhvir Singh', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Arjun Tendulkar', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Duan Jansen', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Noor Ahmad', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Matheesha Pathirana', 'Team'] = 'Chennai Super Kings '

df.loc[df['BOWLING'] == 'Naveen-ul-Haq', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Marcus Stoinis', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Liam Livingstone', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Ishant Sharma', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Kulwant Khejroliya', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Anukul Roy', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Nitish Rana', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Mayank Dagar', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Jayant Yadav', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'Rahul Tewatia', 'Team'] = 'Gujarat Titans'

df.loc[df['BOWLING'] == 'David Wiese', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Vaibhav Arora', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Kuldip Yadav', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Gurnoor Brar', 'Team'] = 'Punjab Kings '

df.loc[df['BOWLING'] == 'Ayush Badoni', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Harshit Rana', 'Team'] = 'Kolkata Knight Riders'

df.loc[df['BOWLING'] == 'Akeal Hosein', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Abhishek Sharma', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Josh Hazlewood', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Mahipal Lomror', 'Team'] = 'Royal Challengers Bangalore'

df.loc[df['BOWLING'] == 'Akash Madhwal', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Kartik Tyagi', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Raghav Goyal', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Tristan Stubbs', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Mohsin Khan', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Swapnil Singh', 'Team'] = 'Lucknow Super Giants '

df.loc[df['BOWLING'] == 'Vivrant Sharma', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Obed McCoy', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Chris Jordan', 'Team'] = 'Mumbai Indians '

df.loc[df['BOWLING'] == 'Joe Root', 'Team'] = 'Rajasthan Royals'

df.loc[df['BOWLING'] == 'Glenn Phillips', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Praveen Dubey', 'Team'] = 'Delhi Capitals '

df.loc[df['BOWLING'] == 'Nitish Kumar Reddy', 'Team'] = 'Sunrisers Hyderabad '

df.loc[df['BOWLING'] == 'Himanshu Sharma', 'Team'] = 'Royal Challengers Bangalore'

# %%
df.iloc[300:350]
# Out:
#                  BOWLING                         Team Match   Match_Number  \
# 300        Piyush Chawla              Mumbai Indians     NaN           NaN
# 301        Cameron Green              Mumbai Indians     NaN           NaN
# 302          Trent Boult             Rajasthan Royals    NaN           NaN
# 303       Sandeep Sharma             Rajasthan Royals    NaN           NaN
# 304  Ravichandran Ashwin             Rajasthan Royals    NaN           NaN
# 305     Yuzvendra Chahal             Rajasthan Royals    NaN           NaN
# 306         Jason Holder             Rajasthan Royals    NaN           NaN
# 307        Naveen-ul-Haq        Lucknow Super Giants     NaN           NaN
# 308        Yudhvir Singh        Lucknow Super Giants     NaN           NaN
# 309           Avesh Khan        Lucknow Super Giants     NaN           NaN
# 310       Marcus Stoinis        Lucknow Super Giants     NaN           NaN
# ...

# %%
df.to_csv('bowlingdata.csv', index=False)
